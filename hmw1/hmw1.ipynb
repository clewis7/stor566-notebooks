# %% [markdown]
# Problem 1
# (a.)
# f(x1,x2) = (x1x2-1)^2 = (x1x2-1)(x1x2-1) - x1^2x2^2-2x1x2+1
# f'(x1, x2) = <2x1x2^2-2x1x2-2x2, 2x1^2x2-2x1>
# f''(x1, x2) = <2x2^2, 4x1x2-1, 4x1x2-2, 2x1^2>

# %%
import numpy as np
from matplotlib import pyplot as plt
import pylab

# %%
def function_a(x1, x2):
    return ((x1*x2)-1)**2

# %%
x1 = np.arange(-1,1,0.01)
x2 = np.arange(-1,1,0.01)
X1, X2 = np.meshgrid(x1, x2)
Z = function_a(X1, X2)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X1, X2, Z, rstride=1, cstride=1, 
                      cmap=cm.RdBu,linewidth=0, antialiased=False)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
# Out:
# /tmp/ipykernel_1752197/4099565652.py:7: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# (b.)

# %%
def function_b(w1,w2):
    return w1-w2

# %%
x1 = np.arange(np.matrix('0 0; 0 0'), np.matrix('5 5; 5 5'), 0.1)
x2 = np.arange(np.matrix('0 0; 0 0'), np.matrix('5 5; 5 5'), 0.1)
X1, X2 = np.meshgrid(x1, x2)
Z = function_a(X1, X2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 x1 = np.arange(np.matrix('0 0; 0 0'), np.matrix('5 5; 5 5'), 0.1)
#       2 x2 = np.arange(np.matrix('0 0; 0 0'), np.matrix('5 5; 5 5'), 0.1)
#       3 X1, X2 = np.meshgrid(x1, x2)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# Problem 3
